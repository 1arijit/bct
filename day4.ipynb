# %%
def factorial(n):
    if(n<=0):
        print("not definable")
        return
    f = 1
    for i in range(1,n+1):
        f*=i
    return f

i = int(input("Enter the number you want factorial of :"))
print(f"the factorial of {i} is {factorial(i)}")
# Out:
# the factorial of 6 is 720

# %%
def fib(n):
    if n < 0 :
        print("not applicable")
        return
    if n==0:
        print(0)
        return
    if n==1:
        print(0,"\n",1)
        return
    first = 0
    second = 1
    next = first+second

    for i in range(n+1):
        print(first)
        next = first+second
        first = second
        second = next

i = int(input("enter how many fib teerms you want: "))
fib(i)
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
import math
def prime(i):
    if i == 1 or i<=0 :
        print("not definable")
        return False
    
    if i==2:
        return True
    for j in range(2,int(math.sqrt(i))+1):
        if(i%j == 0):
            return False
    return True



i = int(input("Enter a number to see if it is prime or not : "))

print(f"the number {i} is prime or not? - {prime(i)}")
# Out:
# the number 6 is prime or not? - False

# %%
def factorial(n):
    if(n<=0):
        print("not definable")
        return
    f = 1
    for i in range(1,n+1):
        f*=i
    return f

import math
def prime(i):
    if i == 1 or i<=0 :
        print("not definable")
        return False
    
    if i==2:
        return True
    for j in range(2,int(math.sqrt(i))+1):
        if(i%j == 0):
            return False
    return True

def fib(n):
    if n < 0 :
        print("not applicable")
        return
    if n==0:
        print(0)
        return
    if n==1:
        print(0,"\n",1)
        return
    a , b = 0,1
    for _ in range(n):
        print(a)
        a,b = b, a+b

def takeInp():
    i = int(input("Enter a number:"))
    return i
def use():
    print("enter 1 to use fibonacci function: ")
    print("Enter 2 use prime function: ")
    print("enter 3 to use factorial function: ")
    i = int(input("Enter a number: "))
    if i == 1:
        fib(takeInp())
    if i == 2:
        print(prime(takeInp()))
    if i == 3:
        print(factorial(takeInp()))


n = 1
while(n!=0):
    use()
    n = int(input("enter any number to continue or 0 to exit: "))
# Out:
# enter 1 to use fibonacci function:
# Enter 2 use prime function:
# enter 3 to use factorial function:
# True
# enter 1 to use fibonacci function:
# Enter 2 use prime function:
# enter 3 to use factorial function:
# 24

# %%
def userData():
    dict1 ={"email":"", "password":"", "name":""}
    for i in dict1:
        dict1[i] = input(f"enter your {i}")

    return arr.append(dict1)

def sign_in():
    dict1 = {"email":"", "password":"", "name":""}
    for i in dict1:
        dict1[i] = input(f"enter your {i}")

    for i in arr:
        if i == dict1:
            print("login successful")
        else:
            print("incorrect data")


def delete_data():
    i = input("Enter your email: ")
    for n in arr:
        if n["email"] == i:
            arr.remove(n)
            print("user remove successfully")
            return
    print("user not found")



def show_data(arr):
    for i in arr:
        print(i)



arr = []

userData(arr)
userData(arr)
userData(arr)
show_data(arr)
delete_data(arr)
show_data(arr)
# Out:
# {'email': 'arijit@gmail', 'password': 'ddd', 'name': 'rrr'}
# {'email': 'aikik@gmail', 'password': 'gggg', 'name': 'arijit'}
# {'email': 'ami@gg', 'password': 'yyy', 'name': 'aimt'}
# user not found
# user not found
# user remove successfully
# {'email': 'arijit@gmail', 'password': 'ddd', 'name': 'rrr'}
# {'email': 'aikik@gmail', 'password': 'gggg', 'name': 'arijit'}

# %%
from tabulate import tabulate

# Initialize an empty list to store user data
users = []

def sign_up():
    """Handles user sign-up and stores the user in the list."""
    name = input("Enter your name: ")
    email = input("Enter your email: ")
    password = input("Enter your password: ")

    # Check if email already exists
    for user in users:
        if user["email"] == email:
            print("Email already registered. Try logging in.")
            return

    user_data = {"name": name, "email": email, "password": password}
    users.append(user_data)
    print("User registered successfully!")

def login():
    """Handles user login by checking credentials."""
    email = input("Enter your email: ")
    password = input("Enter your password: ")

    for user in users:
        if user["email"] == email and user["password"] == password:
            print("Login successful!")
            return
    print("Login failed! Incorrect email or password.")

def display_users():
    """Displays the user list in a tabular format."""
    if not users:
        print("No users found.")
        return

    table = [[i + 1, user["name"], user["email"]] for i, user in enumerate(users)]
    print(tabulate(table, headers=["ID", "Name", "Email"], tablefmt="grid"))

def delete_user():
    """Deletes a user based on the provided email."""
    email = input("Enter email to delete: ")

    for user in users:
        if user["email"] == email:
            users.remove(user)
            print("User deleted successfully!")
            return

    print("User not found!")

# Menu-driven program
while True:
    print("\n1. Sign Up\n2. Login\n3. Display Users\n4. Delete User\n5. Exit")
    choice = input("Enter your choice: ")

    if choice == "1":
        sign_up()
    elif choice == "2":
        login()
    elif choice == "3":
        display_users()
    elif choice == "4":
        delete_user()
    elif choice == "5":
        print("Exiting program...")
        break
    else:
        print("Invalid choice! Please try again.")
